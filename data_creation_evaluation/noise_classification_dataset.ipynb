# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import wfdb
import ast
import json
import os
import tqdm
import re

# %% [markdown]
# # Objective
# Given a 12 lead ECG system, classify the infarction stadium level.
# * Noise may or may not be present in the signal
#
# # Strategy
# * First, train a neural network (NN) to identify the four types of noise ['baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems']
# * Next, train a neural network to identify the infarction stadium (IS) using the 12 lead signal information with an additional layer than indicates what type of noise is in the signal for each lead.
# * In Production, each lead is passed through the noise detection NN to detect noise. That information is then passed to the IS neural network with the signals to make a classification.

# %%
root_directory_path = '/home/lucas/Desktop/programming/classwork/old_school/Senior_project/project/data'
sig_database = pd.read_csv(os.path.join(root_directory_path, 'ptbxl_database.csv'), index_col='ecg_id')
sig_database.columns
# Out:
# Index(['patient_id', 'age', 'sex', 'height', 'weight', 'nurse', 'site',
#        'device', 'recording_date', 'report', 'scp_codes', 'heart_axis',
#        'infarction_stadium1', 'infarction_stadium2', 'validated_by',
#        'second_opinion', 'initial_autogenerated_report', 'validated_by_human',
#        'baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems',
#        'extra_beats', 'pacemaker', 'strat_fold', 'filename_lr', 'filename_hr'],
#       dtype='object')

# %% [markdown]
# Remove the stuff we don't need

# %%
sig_database = sig_database.drop(
    ['patient_id', 'age', 'sex', 'height', 'weight', 'nurse', 'site', 'device', 'recording_date', 'validated_by', 'second_opinion', 'initial_autogenerated_report', 'validated_by_human','extra_beats', 'pacemaker'],
    axis=1
)
print(sig_database.columns)
# Out:
# Index(['report', 'scp_codes', 'heart_axis', 'infarction_stadium1',
#        'infarction_stadium2', 'baseline_drift', 'static_noise', 'burst_noise',
#        'electrodes_problems', 'strat_fold', 'filename_lr', 'filename_hr'],
#       dtype='object')

# %% [markdown]
# # Looking at one Signal
# * We will use the 100 hz sample

# %%
def load_one_sample(path):
    data = wfdb.rdsamp(path)
    signals = np.asmatrix(data[0])
    meta = data[1]
    return signals, meta

one_sample = sig_database.iloc[0]
file_path = one_sample['filename_lr']
signals, meta = load_one_sample(os.path.join(root_directory_path, file_path))
print(signals, meta)
signal = signals.flatten().tolist()[0]
print(signal)
plt.plot(range(len(signal)), signal)
plt.xlabel("Time")
plt.ylabel("Voltage")
plt.show()
# Out:
# [[-0.119 -0.055  0.064 ... -0.026 -0.039 -0.079]
#  [-0.116 -0.051  0.065 ... -0.031 -0.034 -0.074]
#  [-0.12  -0.044  0.076 ... -0.028 -0.029 -0.069]
#  ...
#  [ 0.069  0.    -0.069 ...  0.024 -0.041 -0.058]
#  [ 0.086  0.004 -0.081 ...  0.242 -0.046 -0.098]
#  [ 0.022 -0.031 -0.054 ...  0.143 -0.035 -0.12 ]] {'fs': 100, 'sig_len': 1000, 'n_sig': 12, 'base_date': None, 'base_time': None, 'units': ['mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV'], 'sig_name': ['I', 'II', 'III', 'AVR', 'AVL', 'AVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6'], 'comments': []}
# [-0.119, -0.055, 0.064, 0.086, -0.091, 0.004, -0.069, -0.031, 0.0, -0.026, -0.039, -0.079, -0.116, -0.051, 0.065, 0.083, -0.09, 0.006, -0.064, -0.036, -0.003, -0.031, -0.034, -0.074, -0.12, -0.044, 0.076, 0.082, -0.098, 0.016, -0.058, -0.034, -0.01, -0.028, -0.029, -0.069, -0.117, -0.038, 0.08, 0.077, -0.098, 0.021, -0.05, -0.03, -0.015, -0.023, -0.022, -0.064, -0.103, -0.031, 0.072, 0.066, -0.087, 0.021, -0.045, -0.027, -0.02, -0.019, -0.018, -0.058, -0.097, -0.025, 0.071, 0.061, -0.084, 0.023, -0.036, -0.025, -0.009, -0.014, -0.012, -0.052, -0.119, -0.014, 0.106, 0.066, -0.112, 0.046, -0.029, -0.012, 0.005, -0.008, -0.007, -0.048, -0.096, 0.008, 0.104, 0.044, -0.1, 0.056, -0.023, 0.003, 0.018, 0.002, -0.001, -0.041, -0.048, 0.044, 0.092, 0.002, -0.07, 0.068, -0.015, 0.018, 0.021, 0.009, 0.005, -0.038, -0.037, 0.045, 0.081, -0.004, -0.059, 0.063, -0.05, 0.009, 0.018, 0.022, 0.009, -0.033, -0.032, 0.034, 0.066, -0.001, -0.05, 0.05, -0.075, 0.007, 0.042, 0.042, 0.028, -0.029, -0.002, 0.078, 0.08, -0.038, -0.042, 0.079, -0.064, 0.022, 0.048, 0.045, 0.041, -0.025, -0.017, 0.052, 0.069, -0.017, -0.044, 0.06, -0.065, 0.007, 0.039, 0.046, 0.041, -0.014, -0.115, -0.028, 0.086, 0.071, -0.1, 0.029, -0.059, -0.011, 0.018, 0.015, 0.01, -0.058, -0.156, -0.063, 0.093, 0.109, -0.124, 0.015, -0.055, -0.04, -0.022, -0.027, -0.031, -0.096, -0.153, -0.066, 0.088, 0.109, -0.12, 0.011, -0.058, -0.037, -0.033, -0.03, -0.036, -0.086, -0.143, -0.058, 0.084, 0.1, -0.113, 0.013, -0.059, -0.038, -0.037, -0.034, -0.039, -0.086, -0.109, -0.072, 0.037, 0.09, -0.073, -0.017, -0.065, -0.028, -0.033, -0.036, -0.045, -0.084, -0.153, -0.055, 0.097, 0.104, -0.125, 0.021, -0.063, -0.027, -0.035, -0.027, -0.045, -0.075, -0.178, -0.066, 0.113, 0.122, -0.145, 0.023, -0.036, -0.017, -0.041, -0.034, -0.057, -0.094, -0.152, -0.04, 0.112, 0.096, -0.132, 0.035, 0.048, 0.157, 0.055, 0.001, -0.036, -0.105, 0.043, 0.156, 0.113, -0.1, -0.035, 0.134, 0.031, 0.364, 0.397, 0.309, 0.203, 0.05, 0.469, 0.344, -0.124, -0.406, 0.296, 0.11, -0.29, 0.076, 0.486, 0.539, 0.494, 0.313, 0.371, 0.247, -0.124, -0.309, 0.248, 0.061, -0.636, -0.953, -0.176, 0.132, 0.369, 0.382, -0.002, 0.007, 0.008, -0.002, -0.005, 0.007, -0.672, -1.339, -0.606, -0.277, 0.084, 0.248, -0.078, -0.081, -0.003, 0.08, -0.037, -0.042, -0.463, -0.753, -0.395, -0.235, -0.013, 0.101, -0.132, -0.058, 0.074, 0.094, -0.103, 0.008, -0.199, -0.3, -0.167, -0.129, -0.063, -0.008, -0.132, -0.073, 0.059, 0.102, -0.095, -0.007, -0.054, -0.078, -0.047, -0.08, -0.071, -0.063, -0.14, -0.088, 0.052, 0.114, -0.096, -0.018, -0.026, -0.023, -0.012, -0.053, -0.061, -0.086, -0.138, -0.057, 0.082, 0.097, -0.11, 0.012, -0.015, 0.012, 0.004, -0.037, -0.061, -0.092, -0.179, -0.094, 0.085, 0.136, -0.132, -0.005, -0.011, 0.042, 0.007, -0.022, -0.053, -0.085, -0.18, -0.072, 0.108, 0.126, -0.144, 0.018, -0.009, 0.038, 0.003, -0.016, -0.051, -0.085, -0.119, -0.051, 0.068, 0.084, -0.093, 0.008, -0.004, 0.048, 0.006, -0.013, -0.043, -0.08, -0.158, -0.088, 0.07, 0.123, -0.113, -0.009, -0.001, 0.047, 0.011, -0.01, -0.039, -0.079, -0.138, -0.077, 0.061, 0.108, -0.1, -0.008, 0.004, 0.058, 0.017, -0.008, -0.034, -0.076, -0.117, -0.077, 0.04, 0.097, -0.078, -0.018, 0.017, 0.054, -0.001, -0.003, -0.024, -0.073, -0.133, -0.067, 0.065, 0.1, -0.099, -0.001, 0.01, 0.07, -0.007, -0.019, -0.041, -0.087, -0.126, -0.066, 0.061, 0.096, -0.093, -0.002, 0.005, 0.078, -0.001, -0.029, -0.055, -0.094, -0.149, -0.055, 0.095, 0.102, -0.122, 0.02, 0.027, 0.073, 0.009, -0.018, -0.044, -0.085, -0.156, -0.058, 0.097, 0.107, -0.126, 0.019, 0.035, 0.077, 0.017, -0.013, -0.04, -0.08, -0.139, -0.056, 0.083, 0.097, -0.11, 0.013, 0.039, 0.1, 0.025, -0.005, -0.032, -0.072, -0.124, -0.036, 0.089, 0.08, -0.106, 0.026, 0.035, 0.115, 0.028, -0.006, -0.027, -0.067, -0.073, -0.035, 0.038, 0.054, -0.055, 0.001, 0.018, 0.118, 0.017, -0.003, -0.014, -0.057, -0.078, -0.011, 0.067, 0.044, -0.072, 0.028, 0.039, 0.154, 0.049, 0.017, 0.012, -0.038, -0.123, -0.001, 0.121, 0.062, -0.122, 0.06, 0 ...

# %% [markdown]
# # Noise Identification Dataset
# The issue with this dataset is that there is lots of noise in the signals. Thankfully, the 4 types of noise have been tagged by the lead. I want to clean up this dataset and create a noise classifier, however, there is a lot of garbage labelings. The goal is to first make a pipeline that can parse the strings and map them to the leads, and for the examples where it's not clear,  look at them individually. Additionally, tag the clean ones as clean.
#
# Assumptions we are making:
# - the ';' is replacable with a ',' not a '-'. Meaning it does not represent a range.
# - Any other strings other than lead names, 'nan' or 'alles' will be rejected from the dataset
# - lead order in the 'lead_table' comes from the signal meta data from one of the signal samples

# %%
lead_table = ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
noise_information = sig_database[['baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems']]
error_message = 'erroneous'
clean_message = 'clean'

# %%
def filter_lead_symbols(lead_string):

    # if the string is empty, we want to tag it as clean
    lead_string = str(lead_string).lower()

    if lead_string == 'nan':
        return clean_message

    strings = [s.strip().replace(' ', '') for s in str(lead_string).split(',') if s.replace(' ', '') != '']
    final_symbols = []

    def symbol_decision_tree(string, array):

        # All values
        if re.search(r'alle', string):
            array.extend(lead_table)
            return
    
        # Dash Present
        if '-' in string:
            symbol_range = string.split('-')

            # check if the second value is just a number, if so, add a 'v' to the front of it
            if symbol_range[-1].isdigit():
                symbol_range[-1] = 'v' + symbol_range[-1]

            # Check if the range is possible, if not, then it is garbage
            if symbol_range[0] in lead_table and symbol_range[-1] in lead_table:
                start_index, end_index = lead_table.index(symbol_range[0]), lead_table.index(symbol_range[-1])
                symbols = lead_table[start_index: end_index + 1]
                array.extend(symbols)

            # Garbage
            else:
                array.append(error_message)

        # no dash
        if string in lead_table:
            array.append(string)

    for s in strings:
        symbol_decision_tree(s, final_symbols)

    print(f"{lead_string} -> {final_symbols}")

    return final_symbols if len(final_symbols) and error_message not in final_symbols else error_message

# %%
test_strings = ['v2-6', 'v3-4', 'v5-6', 'v4-5']

for t in test_strings:
    print(filter_lead_symbols(t))
# Out:
# v2-6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
# ['v2', 'v3', 'v4', 'v5', 'v6']
# v3-4 -> ['v3', 'v4']
# ['v3', 'v4']
# v5-6 -> ['v5', 'v6']
# ['v5', 'v6']
# v4-5 -> ['v4', 'v5']
# ['v4', 'v5']

# %%
# Apply the filter to the full data frame
noise_information = noise_information.map(lambda x: filter_lead_symbols(x))
print(len(noise_information))
# Out:
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , iii,avr,avf -> ['iii', 'avr', 'avf']
#  , v1 -> ['v1']
#  , ii,avf -> ['ii', 'avf']
#  , ii-avl,avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
#  , v3 -> ['v3']
#  , ii-avl,avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , iii -> ['iii']
#  , v6 -> ['v6']
#  , avf -> ['avf']
#  , ii-avf,v5,v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v5', 'v6']
#  , v1 -> ['v1']
#  , iii,avf -> ['iii', 'avf']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , iii,v3,v6 -> ['iii', 'v3', 'v6']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v6 -> ['v6']
#  , iii,avf -> ['iii', 'avf']
#  , v6 -> ['v6']
#  , ii-avf,v5 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v5']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , avr -> ['avr']
#  , v2 -> ['v2']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii-v2 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
#  , v1v6 -> []
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v1  -> ['v1']
#  , avl -> ['avl']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , iii,v4 -> ['iii', 'v4']
#  , v3 -> ['v3']
#  , ii,iii,avf-v6 -> ['ii', 'iii', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5  -> ['v5']
#  , iii,avl -> ['iii', 'avl']
# v5-6,   -> ['v5', 'v6']
# v2,   -> ['v2']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1,2 -> ['v1']
#  , 1 -> []
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , iii,v1 -> ['iii', 'v1']
#  , v4,v5 -> ['v4', 'v5']
#  , iii,v3-v6 -> ['iii', 'v3', 'v4', 'v5', 'v6']
#  , v1-v3 -> ['v1', 'v2', 'v3']
#  , v6 -> ['v6']
#  , v4 -> ['v4']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v2 -> ['v2']
#  , iii,v5,v6 -> ['iii', 'v5', 'v6']
# v4,   -> ['v4']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , i-avf,v5,v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v5', 'v6']
#  , v1,v6 -> ['v1', 'v6']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v3 -> ['v3']
#  , v3,5,6 -> ['v3']
#  , i,ii,avr -> ['i', 'ii', 'avr']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v4 -> ['v4']
#  , v5,v6 -> ['v5', 'v6']
#  , v4 -> ['v4']
#  , iii,avf -> ['iii', 'avf']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v4,v5 -> ['v4', 'v5']
#  , v2 -> ['v2']
#  , v1 -> ['v1']
#  , ii-v1 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , i,iii-v1 -> ['i', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v4 -> ['v4']
#  , v6 -> ['v6']
# v5,   -> ['v5']
#  , v6 -> ['v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v2 -> ['v2']
#  , v4 -> ['v4']
#  , v2 -> ['v2']
#  , v4-6 -> ['v4', 'v5', 'v6']
# v5-6,   -> ['v5', 'v6']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5 -> ['v5']
#  , v3 -> ['v3']
#  , v4 -> ['v4']
# v3,   -> ['v3']
# v3, v1-6 -> ['v3', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alle -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i,iii,avl,avf -> ['i', 'iii', 'avl', 'avf']
#  , v3 -> ['v3']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v1 -> ['v1']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , iii,avf,v4 -> ['iii', 'avf', 'v4']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# v2,   -> ['v2']
# v6,   -> ['v6']
# v5,   -> ['v5']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3 -> ['v3']
#  , v2 -> ['v2']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v6 -> ['v6']
#  , iii,avf -> ['iii', 'avf']
# v6,   -> ['v6']
#  , v2 -> ['v2']
#  , v1 -> ['v1']
#  , iii,avf -> ['iii', 'avf']
#  , iii,avl -> ['iii', 'avl']
#  , v4 -> ['v4']
#  , v3, v6 -> ['v3', 'v6']
# v3,   -> ['v3']
#  , i-avl,avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v3 -> ['v3']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i,ii,avr,v1 -> ['i', 'ii', 'avr', 'v1']
#  , v1 -> ['v1']
# v3,6,   -> ['v3']
#  , ii,iii,avl,avf -> ['ii', 'iii', 'avl', 'avf']
# v2,3,   -> ['v2']
#  , v5,6 -> ['v5']
#  , 2 -> []
#  , v1,3,4,6 -> ['v1']
#  , v6 -> ['v6']
#  , v5,6 -> ['v5']
#  , v1,2 -> ['v1']
#  , v3 -> ['v3']
# v6,   -> ['v6']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , v1-v3 -> ['v1', 'v2', 'v3']
#  , ii-avl -> ['ii', 'iii', 'avr', 'avl']
#  , ii-avf,v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v2-v5 -> ['v2', 'v3', 'v4', 'v5']
#  , ii,avf -> ['ii', 'avf']
#  , v3,v6 -> ['v3', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v1 -> ['v1']
#  , i,ii,avr,v2-v6 -> ['i', 'ii', 'avr', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3,v4 -> ['v3', 'v4']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , v1,3,5 -> ['v1']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v5 stark! -> []
#  , v2,v3 -> ['v2', 'v3']
#  , ii,iii -> ['ii', 'iii']
#  , i,ii,v3 -> ['i', 'ii', 'v3']
#  , v1,v2 -> ['v1', 'v2']
#  , v5,v6 -> ['v5', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v1,v4-v6 -> ['v1', 'v4', 'v5', 'v6']
#  , v4 -> ['v4']
#  , v5 -> ['v5']
#  , v4 -> ['v4']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , iii,avl -> ['iii', 'avl']
#  , v3 stark -> []
# alle, alle -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v4-6,   -> ['v4', 'v5', 'v6']
#  , v2,3 -> ['v2']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v3, 5 -> ['v3']
#  , iii -> ['iii']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v1,   -> ['v1']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
# v1-2,   -> ['v1', 'v2']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v3 -> ['v3']
# v2,   -> ['v2']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , ii,iii -> ['ii', 'iii']
#  , v4 -> ['v4']
# v1,   -> ['v1']
#  , i-v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3 -> ['v3']
#  , v3 -> ['v3']
#  , i-avl,v4,v5 -> ['i', 'ii', 'iii', 'avr', 'avl', 'v4', 'v5']
#  , v1 -> ['v1']
# v2,6,   -> ['v2']
#  , v6 -> ['v6']
#  , v5;v6 -> []
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v1 -> ['v1']
#  , ii-v1 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v2,v3 -> ['v2', 'v3']
#  , v1 -> ['v1']
#  , ii-v4 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4']
#  , drift -> []
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v4 -> ['v4']
#  , v6 -> ['v6']
#  , v5, v6 -> ['v5', 'v6']
#  , iii,v6 -> ['iii', 'v6']
#  , v5 -> ['v5']
#  , drift -> []
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v5,v6 -> ['v5', 'v6']
#  , v3 -> ['v3']
#  , stark -> []
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i,ii,v2,v3 -> ['i', 'ii', 'v2', 'v3']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i,iii,avl,v3 -> ['i', 'iii', 'avl', 'v3']
# v2,   -> ['v2']
# v1,   -> ['v1']
#  , v2,3 -> ['v2']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v4 -> ['v4']
#  , ii,avf,v3-v6 -> ['ii', 'avf', 'v3', 'v4', 'v5', 'v6']
# v4,   -> ['v4']
# v1,6,   -> ['v1']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , i,ii,avr,avf -> ['i', 'ii', 'avr', 'avf']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , iii,v5,v6 -> ['iii', 'v5', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , iii,avl -> ['iii', 'avl']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , iii,v4,v5 -> ['iii', 'v4', 'v5']
#  , i,iii -> ['i', 'iii']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , iii,avl -> ['iii', 'avl']
#  , v6 -> ['v6']
#  , v3,v6 -> ['v3', 'v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , v3 -> ['v3']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v6 -> ['v6']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , iii,avf -> ['iii', 'avf']
# i-iii,v1-v3,   -> ['i', 'ii', 'iii', 'v1', 'v2', 'v3']
#  , i,ii,avl-avf -> ['i', 'ii', 'avl', 'avf']
# v3, v1 -> ['v3', 'v1']
#  , v5 -> ['v5']
#  , v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
#  , v1 -> ['v1']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
#  , v1 stark -> []
#  , v2 -> ['v2']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v5 -> ['v5']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v3 -> ['v3']
#  , avr,v1 -> ['avr', 'v1']
#  , v1 -> ['v1']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , avl,v2,v5,v6 -> ['avl', 'v2', 'v5', 'v6']
#  , v1 -> ['v1']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v4-6 -> ['v4', 'v5', 'v6']
#  , iii,avl -> ['iii', 'avl']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,   -> ['v1']
# v4,5,   -> ['v4']
#  , v6 -> ['v6']
#  , v2, v6 -> ['v2', 'v6']
# v1-6,   -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
# v2,   -> ['v2']
# v2,3,   -> ['v2']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , avl,avr -> ['avl', 'avr']
#  , ii,v3 -> ['ii', 'v3']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , iii,v3 -> ['iii', 'v3']
#  , v5,v6 -> ['v5', 'v6']
# v3,   -> ['v3']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v1,v2 -> ['v1', 'v2']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i -> ['i']
# v6,   -> ['v6']
#  , v6 -> ['v6']
#  , v1-v4 -> ['v1', 'v2', 'v3', 'v4']
#  , ii,iii -> ['ii', 'iii']
# v4-v6,   -> ['v4', 'v5', 'v6']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v4-6 -> ['v4', 'v5', 'v6']
#  , v5-6 -> ['v5', 'v6']
#  , iii,avf,v1 -> ['iii', 'avf', 'v1']
# v6,   -> ['v6']
# v3,   -> ['v3']
#  , iii,avl,v5 -> ['iii', 'avl', 'v5']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v4, v6 -> ['v4', 'v6']
#  , i,ii,avl-avf -> ['i', 'ii', 'avl', 'avf']
#  , v1 -> ['v1']
#  , v7 -> []
# v4, v5,   -> ['v4', 'v5']
# stufen v5,   -> []
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v5 -> ['v5']
#  , i-v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , stark -> []
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
# v6,   -> ['v6']
#  , v5 -> ['v5']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v4 -> ['v4']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v2,3,4 -> ['v2']
# alle, i,ii -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'i', 'ii']
#  , v1,6 -> ['v1']
# v5,   -> ['v5']
#  , i-avf,v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v6']
#  , v1 -> ['v1']
#  , iii,avf -> ['iii', 'avf']
#  , i,ii,avr,v6 -> ['i', 'ii', 'avr', 'v6']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii  -> ['ii']
#  , v6 -> ['v6']
#  , v3-v6 -> ['v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v3,v6 -> ['v3', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i,iii,avl,v5,v6 -> ['i', 'iii', 'avl', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , i -> ['i']
#  , v6 -> ['v6']
#  , i,iii,avl,v3,v6 -> ['i', 'iii', 'avl', 'v3', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v4 -> ['v4']
#  , iii,avf -> ['iii', 'avf']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
#  , v2 -> ['v2']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v1,2,3,4,5,6 -> ['v1']
#  , v2,v3 -> ['v2', 'v3']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , v1,v6 -> ['v1', 'v6']
#  , ii-avl -> ['ii', 'iii', 'avr', 'avl']
#  , v2,v6 -> ['v2', 'v6']
#  , v5 -> ['v5']
#  , v1,v2 -> ['v1', 'v2']
#  , iii,avf,v1-v6 -> ['iii', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3-v6 -> ['v3', 'v4', 'v5', 'v6']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , v1,v4 -> ['v1', 'v4']
#  , v1 -> ['v1']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v1-v3 -> ['v1', 'v2', 'v3']
#  , v5,v6 -> ['v5', 'v6']
# v2,   -> ['v2']
#  , ii-v2 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , avr -> ['avr']
#  , v1,6 -> ['v1']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v5,v6 -> ['v5', 'v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v4 -> ['v4']
#  , v2-5 -> ['v2', 'v3', 'v4', 'v5']
#  , v3 -> ['v3']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3 -> ['v3']
#  , i,avr -> ['i', 'avr']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , i-v1,v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , ii,iii.avf,v3 -> ['ii', 'v3']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v6 -> ['v6']
# v5-6,   -> ['v5', 'v6']
#  , v4 -> ['v4']
#  , drift -> []
#  , v2 -> ['v2']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
# alle, v3 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v3']
#  , v6 -> ['v6']
#  , v2,v4 -> ['v2', 'v4']
#  , v2 -> ['v2']
#  , v5 -> ['v5']
# i,iii,v3,v4,   -> ['i', 'iii', 'v3', 'v4']
#  , v6 -> ['v6']
# v5-6,   -> ['v5', 'v6']
# v3-v5,   -> ['v3', 'v4', 'v5']
#  , v6 -> ['v6']
#  , ii,avf -> ['ii', 'avf']
#  , v4 -> ['v4']
#  , v3-v4 -> ['v3', 'v4']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# v3,   -> ['v3']
#  , v6 -> ['v6']
#  , iii,v4 -> ['iii', 'v4']
#  , v1 -> ['v1']
# v2,   -> ['v2']
#  , i,iii-v1 -> ['i', 'iii', 'avr', 'avl', 'avf', 'v1']
# v3, avf,   -> ['v3', 'avf']
#  , v1 -> ['v1']
#  , i - avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , iii,avf,v5,v6 -> ['iii', 'avf', 'v5', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , iii,avl -> ['iii', 'avl']
#  , v5,v6 -> ['v5', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , iii -> ['iii']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-avl -> ['ii', 'iii', 'avr', 'avl']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3 -> ['v3']
#  , iii,avl,avf -> ['iii', 'avl', 'avf']
#  , v4 -> ['v4']
#  , v1 -> ['v1']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2,3 -> ['v2']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v2 -> ['v2']
#  , v2 -> ['v2']
#  , v5 -> ['v5']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v6 -> ['v6']
#  , iii -> ['iii']
#  , iii,avl,v6 -> ['iii', 'avl', 'v6']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , iii-avf -> ['iii', 'avr', 'avl', 'avf']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , i - avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , i,ii,v1,v5,v6 -> ['i', 'ii', 'v1', 'v5', 'v6']
#  , ii,iii -> ['ii', 'iii']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v2,   -> ['v2']
#  , v5,v6 -> ['v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , i - avf,v3 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v3']
# ii,iii,avf,v1-v3, v6 -> ['ii', 'iii', 'avf', 'v1', 'v2', 'v3', 'v6']
#  , v3 -> ['v3']
#  , iii,v3 -> ['iii', 'v3']
#  , v3-v6 -> ['v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v5 -> ['v5']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v2 -> ['v2']
#  , ii,iii -> ['ii', 'iii']
#  , v1,v2 -> ['v1', 'v2']
#  , ii,iii,avf,v6 -> ['ii', 'iii', 'avf', 'v6']
#  , v5 -> ['v5']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2 -> ['v2']
#  , v5,6 -> ['v5']
#  , ii-v2 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
#  , v2 -> ['v2']
#  , v2 -> ['v2']
#  , v5,v6 -> ['v5', 'v6']
#  , avr,v4 -> ['avr', 'v4']
#  , v5,v6 -> ['v5', 'v6']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , v2 -> ['v2']
#  , v4 stark -> []
#  , v5,v6 -> ['v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v4,v5 -> ['v4', 'v5']
#  , v5 -> ['v5']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v1 -> ['v1']
#  , v2 -> ['v2']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii-avr -> ['ii', 'iii', 'avr']
#  , v1 -> ['v1']
#  , iii -> ['iii']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , v5-6 -> ['v5', 'v6']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii, iii -> ['ii', 'iii']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3,4,6 -> ['v3']
#  , v5,v6 -> ['v5', 'v6']
#  , v3 -> ['v3']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v5,v6 -> ['v5', 'v6']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , iii,avf -> ['iii', 'avf']
#  , v1,v5,v6 -> ['v1', 'v5', 'v6']
#  , iii,avf -> ['iii', 'avf']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , iii,v3 -> ['iii', 'v3']
#  , v1 -> ['v1']
#  , iii,avf -> ['iii', 'avf']
#  , ii,iii -> ['ii', 'iii']
# v3,   -> ['v3']
#  , v5 -> ['v5']
#  , v1 -> ['v1']
#  , v4 -> ['v4']
# v3,   -> ['v3']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , i,iii-avf -> ['i', 'iii', 'avr', 'avl', 'avf']
#  , i,avl,v3 -> ['i', 'avl', 'v3']
#  , v3-4 -> ['v3', 'v4']
# v3,   -> ['v3']
#  , v4 -> ['v4']
# v6, v6 -> ['v6', 'v6']
#  , ii-v1 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v6 -> ['v6']
# v5, v6,   -> ['v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , iii,avf,v4 -> ['iii', 'avf', 'v4']
# napf,   -> []
#  , iii,avl -> ['iii', 'avl']
# v2,   -> ['v2']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# stufe v3,   -> []
#  , ii-avf,v4-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v4', 'v5', 'v6']
# ii,avl,avr,   -> ['ii', 'avl', 'avr']
#  , drift -> []
#  , v6 -> ['v6']
#  , v4 -> ['v4']
# alles, alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , avl,v5 -> ['avl', 'v5']
#  , iii,v5 -> ['iii', 'v5']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , v1,v6 -> ['v1', 'v6']
#  , v5,6 -> ['v5']
#  , v2 -> ['v2']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , iii,v2 -> ['iii', 'v2']
#  , v1 -> ['v1']
#  , v3 -> ['v3']
#  , v5 -> ['v5']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
# i,v1,   -> ['i', 'v1']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , i,iii,avf -> ['i', 'iii', 'avf']
#  , v5 -> ['v5']
#  , v1 -> ['v1']
#  , v3 -> ['v3']
#  , iii -> ['iii']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v5 -> ['v5']
#  , v6 -> ['v6']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v5,v6 -> ['v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v3 -> ['v3']
#  , iii,avl,avf -> ['iii', 'avl', 'avf']
#  , v1-v3 -> ['v1', 'v2', 'v3']
#  , v2 -> ['v2']
#  , v6 -> ['v6']
#  , i -> ['i']
#  , v6 -> ['v6']
#  , v2,v5 -> ['v2', 'v5']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , iii,avl -> ['iii', 'avl']
#  , v2 -> ['v2']
#  , v2-v4 -> ['v2', 'v3', 'v4']
#  , v6 -> ['v6']
#  , i-avf,v5,v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v5', 'v6']
#  , v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , i,avl -> ['i', 'avl']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
# v6, v6 -> ['v6', 'v6']
#  , v6 -> ['v6']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v3 -> ['v3']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , v1,v5,v6 -> ['v1', 'v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v2 -> ['v2']
#  , v2,v3 -> ['v2', 'v3']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1,v5,v6 -> ['v1', 'v5', 'v6']
#  , v4 -> ['v4']
#  , v2,v3 -> ['v2', 'v3']
#  , v2,v3 -> ['v2', 'v3']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v5 -> ['v5']
#  , v6 -> ['v6']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , avl,v2 -> ['avl', 'v2']
#  , ii,iii -> ['ii', 'iii']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , iii -> ['iii']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v3 -> ['v3']
#  , i,ii,avr -> ['i', 'ii', 'avr']
#  , i,ii -> ['i', 'ii']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v4-6 -> ['v4', 'v5', 'v6']
# v1,   -> ['v1']
# v1,   -> ['v1']
# v3,   -> ['v3']
#  , v1,6 -> ['v1']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v1-2, i-ii -> ['v1', 'v2', 'i', 'ii']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# v6,   -> ['v6']
#  , v6 -> ['v6']
# v4,5,   -> ['v4']
# i-avf,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-avf,v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v6']
# v3-4,   -> ['v3', 'v4']
#  , ii-v3 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3']
#  , v2 -> ['v2']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
#  , v4 -> ['v4']
# v6,   -> ['v6']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5 -> ['v5']
# i-iii,   -> ['i', 'ii', 'iii']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , ii-avl,avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v5-6 -> ['v5', 'v6']
#  , i,avl -> ['i', 'avl']
#  , v2 -> ['v2']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v2 -> ['v2']
#  , ii-v1 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# v6,   -> ['v6']
# v6,   -> ['v6']
#  , iii,avl -> ['iii', 'avl']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , drift -> []
#  , iii,avl -> ['iii', 'avl']
#  , v3 -> ['v3']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v1-v4 -> ['v1', 'v2', 'v3', 'v4']
#  , v1,v6 -> ['v1', 'v6']
#  , i,iii-avf -> ['i', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
#  , ii-avl -> ['ii', 'iii', 'avr', 'avl']
#  , v2 -> ['v2']
#  , v4 -> ['v4']
#  , i,ii,iii,avl,avr,avf -> ['i', 'ii', 'iii', 'avl', 'avr', 'avf']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
# v6,   -> ['v6']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v4,v5 -> ['v4', 'v5']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avf,v4-v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v2 -> ['v2']
#  , v3 -> ['v3']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# v1,   -> ['v1']
#  , v3,v6 -> ['v3', 'v6']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , iii,avf -> ['iii', 'avf']
#  , v2 -> ['v2']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1,v2 -> ['v1', 'v2']
#  , v3 -> ['v3']
#  , ii,iii,avf,v4 -> ['ii', 'iii', 'avf', 'v4']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , iii,avf -> ['iii', 'avf']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v6 -> ['v6']
#  , iii,avf -> ['iii', 'avf']
#  , iii,avf -> ['iii', 'avf']
#  , v6 -> ['v6']
#  , iii,avf -> ['iii', 'avf']
#  , v1,v2 -> ['v1', 'v2']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , ii-avf,v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , v1,v2,v3 -> ['v1', 'v2', 'v3']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii-v2 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , ii-avl -> ['ii', 'iii', 'avr', 'avl']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , v1 -> ['v1']
#  , v3 -> ['v3']
#  , iii,v1-v3 -> ['iii', 'v1', 'v2', 'v3']
#  , v2,5 -> ['v2']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v4 -> ['v4']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , v5,v6 -> ['v5', 'v6']
#  , v1 -> ['v1']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , v1 -> ['v1']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , iii-avf -> ['iii', 'avr', 'avl', 'avf']
#  , v2 -> ['v2']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v1 -> ['v1']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , iii,avf -> ['iii', 'avf']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
# i, iii, avf,   -> ['i', 'iii', 'avf']
# v1-6,   -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v5-6,   -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , v2 -> ['v2']
# v1-6, v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii-avl,v6 -> ['ii', 'iii', 'avr', 'avl', 'v6']
#  , ii,iii -> ['ii', 'iii']
#  , v3 -> ['v3']
#  , v 4 -> ['v4']
#  , avf -> ['avf']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i,ii -> ['i', 'ii']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-iii, avl -> ['i', 'ii', 'iii', 'avl']
#  , v2 -> ['v2']
#  , v5,v6 -> ['v5', 'v6']
# v5,   -> ['v5']
#  , v5,v6 -> ['v5', 'v6']
#  , v3,v5 -> ['v3', 'v5']
#  , v1 -> ['v1']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# v,v3,   -> ['v3']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
# v1,2,   -> ['v1']
# v6,   -> ['v6']
#  , i-v5 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5']
#  , v6 -> ['v6']
# v1,6,   -> ['v1']
#  , v1 -> ['v1']
#  , ii,iii -> ['ii', 'iii']
# v1,   -> ['v1']
# v1-6,   -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3 -> ['v3']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii,iii,v5,v6 -> ['ii', 'iii', 'v5', 'v6']
# v4-6, v4-6 -> ['v4', 'v5', 'v6', 'v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
#  , v3 -> ['v3']
# v5-6,   -> ['v5', 'v6']
# v6,   -> ['v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v1 -> ['v1']
# v4-v6,   -> ['v4', 'v5', 'v6']
#  , v4 -> ['v4']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v3-v6 -> ['v3', 'v4', 'v5', 'v6']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , v1-v3 -> ['v1', 'v2', 'v3']
#  , v3 -> ['v3']
#  , stark -> []
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v5,v6 -> ['v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v2 -> ['v2']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v3 -> ['v3']
#  , ii,avf -> ['ii', 'avf']
#  , v2 -> ['v2']
#  , iii -> ['iii']
#  , v5 -> ['v5']
#  , v5 -> ['v5']
#  , iii -> ['iii']
#  , v6 -> ['v6']
#  , v1,4 -> ['v1']
#  , v4 -> ['v4']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , ii-avl,v6 -> ['ii', 'iii', 'avr', 'avl', 'v6']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , iii,v1 -> ['iii', 'v1']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , i,iii,v1-v6 -> ['i', 'iii', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , iii,avf -> ['iii', 'avf']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , v3 -> ['v3']
#  , v1 -> ['v1']
#  , iii,avl -> ['iii', 'avl']
#  , i,ii,avf -> ['i', 'ii', 'avf']
#  , i-avr,v& -> ['i', 'ii', 'iii', 'avr']
#  , v3-v5 -> ['v3', 'v4', 'v5']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v2,v5,v6 -> ['v2', 'v5', 'v6']
#  , v4 -> ['v4']
# avl,avf,   -> ['avl', 'avf']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v3-v6 -> ['v3', 'v4', 'v5', 'v6']
# i-avr,v4,   -> ['i', 'ii', 'iii', 'avr', 'v4']
#  , ii,iii -> ['ii', 'iii']
#  , iii,avf -> ['iii', 'avf']
#  , iii,avl,v5,v6 -> ['iii', 'avl', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avl,avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v4,5,   -> ['v4']
#  , v2 -> ['v2']
#  , v3 -> ['v3']
#  , v1 -> ['v1']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5 -> ['v5']
#  , v1 -> ['v1']
#  , v4,v6 -> ['v4', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , iii -> ['iii']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v1,v6 -> ['v1', 'v6']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2 -> ['v2']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1,v2 -> ['v1', 'v2']
#  , ii-avr -> ['ii', 'iii', 'avr']
#  , iii,avl,v4 -> ['iii', 'avl', 'v4']
#  , v3 -> ['v3']
#  , v3 -> ['v3']
#  , ii-v3 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3']
#  , v3 -> ['v3']
# v6,   -> ['v6']
#  , v6 -> ['v6']
#  , v5,6 -> ['v5']
#  , iii,v2 -> ['iii', 'v2']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,   -> ['v1']
#  , v6 -> ['v6']
#  , v4 -> ['v4']
#  , v2 -> ['v2']
#  , iii,avl -> ['iii', 'avl']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
# v5,   -> ['v5']
#  , v5 -> ['v5']
# v2,   -> ['v2']
# v6,   -> ['v6']
#  , v1 -> ['v1']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v6 -> ['v6']
# i,v1,v2,v4-v6,   -> ['i', 'v1', 'v2', 'v4', 'v5', 'v6']
# v2-3,   -> ['v2', 'v3']
#  , v6 -> ['v6']
#  , v1, 4 -> ['v1']
# v2 - v4,   -> ['v2', 'v3', 'v4']
#  , i-avr,v1,v3-v6 -> ['i', 'ii', 'iii', 'avr', 'v1', 'v3', 'v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v3 -> ['v3']
# v6,   -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v2,v3 -> ['v2', 'v3']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v2, v6 -> ['v2', 'v6']
#  , v6 -> ['v6']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , i,avl,v3 -> ['i', 'avl', 'v3']
#  , v1 -> ['v1']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v1 -> ['v1']
#  , v5,v6 -> ['v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# v6,   -> ['v6']
#  , iii,v3-v6 -> ['iii', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
# ii,iii,avf,v4,v5,v6,   -> ['ii', 'iii', 'avf', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , ii,iii, v3 - v5 -> ['ii', 'iii', 'v3', 'v4', 'v5']
#  , ii,iii,v5,v6 -> ['ii', 'iii', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v2,v4 -> ['v2', 'v4']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , v6 -> ['v6']
#  , v4 -> ['v4']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , iii,avl,v1,v2,v4 -> ['iii', 'avl', 'v1', 'v2', 'v4']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v3 -> ['v3']
#  , v1 -> ['v1']
#  , v3 -> ['v3']
#  , i,ii,avr -> ['i', 'ii', 'avr']
#  , v4 - v6 -> ['v4', 'v5', 'v6']
# v1,v2,v4,   -> ['v1', 'v2', 'v4']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , i,ii,avl -> ['i', 'ii', 'avl']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v4 -> ['v4']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v6 -> ['v6']
#  , v2 -> ['v2']
#  , iii,avl -> ['iii', 'avl']
#  , iii,avf,v2,v4-v6 -> ['iii', 'avf', 'v2', 'v4', 'v5', 'v6']
#  , v3,v4 -> ['v3', 'v4']
# avl,   -> ['avl']
#  , v3 -> ['v3']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v5,v6 -> ['v5', 'v6']
#  , v2 -> ['v2']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i,avr -> ['i', 'avr']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , ii-avl,avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# v4,   -> ['v4']
#  , v1,4 -> ['v1']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , ii-avl -> ['ii', 'iii', 'avr', 'avl']
#  , v5 -> ['v5']
#  , i,ii,avr -> ['i', 'ii', 'avr']
#  , v2 -> ['v2']
#  , v6 -> ['v6']
#  , v1,4,5,6 -> ['v1']
#  , v3 -> ['v3']
#  , i-avf,v5,v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , v5,v6 -> ['v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v5,v6 -> ['v5', 'v6']
#  , v4,v6 -> ['v4', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , iii,v4 -> ['iii', 'v4']
#  , v5 -> ['v5']
#  , v1,v6 -> ['v1', 'v6']
#  , v2 -> ['v2']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2,v5 -> ['v2', 'v5']
#  , v3 -> ['v3']
#  , iii,avl -> ['iii', 'avl']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , iii -> ['iii']
# v4-6,   -> ['v4', 'v5', 'v6']
#  , v1 -> ['v1']
#  , v5 -> ['v5']
#  , v1 -> ['v1']
# v6,   -> ['v6']
#  , v4-v6 -> ['v4', 'v5', 'v6']
# v4-6,   -> ['v4', 'v5', 'v6']
# v3,   -> ['v3']
# v1, 3,   -> ['v1']
#  , v6 -> ['v6']
#  , v5-6 -> ['v5', 'v6']
#  , avr,avf -> ['avr', 'avf']
#  , v2 -> ['v2']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i,ii,avr,avf -> ['i', 'ii', 'avr', 'avf']
#  , v2 -> ['v2']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , ii,iii -> ['ii', 'iii']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
# v6,   -> ['v6']
#  , v1 -> ['v1']
# v5,   -> ['v5']
#  , v1 -> ['v1']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii,iii-avf,v3 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v3']
# i,iii,avl,v3,v4,   -> ['i', 'iii', 'avl', 'v3', 'v4']
#  , v4,v6 -> ['v4', 'v6']
#  , v2,4 -> ['v2']
#  , v1 -> ['v1']
#  , v4 -> ['v4']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1 -> ['v1']
# v4,   -> ['v4']
#  , v6 -> ['v6']
#  , v2, v6 -> ['v2', 'v6']
# v5, ii-avf,v5 -> ['v5', 'ii', 'iii', 'avr', 'avl', 'avf', 'v5']
#  , v5 -> ['v5']
# v1,   -> ['v1']
#  , i-avr,v2 -> ['i', 'ii', 'iii', 'avr', 'v2']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v3 -> ['v3']
#  , v5, v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-avl,avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v5 -> ['v5']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v4 stark -> []
#  , v3 -> ['v3']
#  , i,iii -> ['i', 'iii']
#  , v3,v6 -> ['v3', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , iii,avf -> ['iii', 'avf']
#  , v2 -> ['v2']
#  , v6 -> ['v6']
#  , avf -> ['avf']
#  , v3 -> ['v3']
#  , v4 -> ['v4']
#  , v3,v4 -> ['v3', 'v4']
# v1,   -> ['v1']
#  , v2 -> ['v2']
#  , v4 -> ['v4']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , i-avf,v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v6']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v2 -> ['v2']
#  , v5,v6 -> ['v5', 'v6']
#  , v3,v4 -> ['v3', 'v4']
# v1-v3, v6 -> ['v1', 'v2', 'v3', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v4 -> ['v4']
#  , v3,v4 -> ['v3', 'v4']
#  , v6 -> ['v6']
#  , v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
#  , i,ii,avf,v6 -> ['i', 'ii', 'avf', 'v6']
#  , v5,v6 -> ['v5', 'v6']
# avf,   -> ['avf']
#  , v5 -> ['v5']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
# v1-v3,   -> ['v1', 'v2', 'v3']
#  , iii,avl,avf -> ['iii', 'avl', 'avf']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# i,v1-v4,   -> ['i', 'v1', 'v2', 'v3', 'v4']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
#  , v1 -> ['v1']
#  , v5 -> ['v5']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
# v3,   -> ['v3']
#  , iii,avl,v1-v4 -> ['iii', 'avl', 'v1', 'v2', 'v3', 'v4']
#  , i-avf,v3 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v3']
#  , v5,v6 -> ['v5', 'v6']
#  , iii-v2 -> ['iii', 'avr', 'avl', 'avf', 'v1', 'v2']
#  , v4,v6 -> ['v4', 'v6']
#  , v2 -> ['v2']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2 -> ['v2']
#  , v2-v4 -> ['v2', 'v3', 'v4']
#  , v1,v2;v6 -> ['v1']
#  , v2 -> ['v2']
#  , v5,v6 -> ['v5', 'v6']
#  , i,avl,v3 -> ['i', 'avl', 'v3']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v3 -> ['v3']
#  , v2 -> ['v2']
#  , v1,2 -> ['v1']
#  , v1 -> ['v1']
#  , avl -> ['avl']
# v4, v4 -> ['v4', 'v4']
# v2,   -> ['v2']
#  , i,ii,avl-avf,v5,v6 -> ['i', 'ii', 'avl', 'avf', 'v5', 'v6']
#  , v3 -> ['v3']
#  , avr,avf -> ['avr', 'avf']
#  , v1 -> ['v1']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v4 -> ['v4']
#  , v2 -> ['v2']
#  , ii-v1 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5 -> ['v5']
# v1,   -> ['v1']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2 -> ['v2']
#  , starke drift -> []
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
# v2,   -> ['v2']
#  , v5,v6 -> ['v5', 'v6']
#  , v5-6 -> ['v5', 'v6']
#  , v1,3 -> ['v1']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alle abl.,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v4 -> ['v4']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v1, v3 -> ['v1', 'v3']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v2 -> ['v2']
#  , v5-v6 -> ['v5', 'v6']
#  , v4 -> ['v4']
#  , v2 -> ['v2']
#  , drift -> []
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
#  , v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
#  , i,iii,avl,v5,v6 -> ['i', 'iii', 'avl', 'v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v1 -> ['v1']
#  , v2 -> ['v2']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , iii,avl,avf -> ['iii', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , i,avl -> ['i', 'avl']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , v5 -> ['v5']
#  , v4 -> ['v4']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-iii,avf -> ['i', 'ii', 'iii', 'avf']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v3 -> ['v3']
#  , ii,iii,v6 -> ['ii', 'iii', 'v6']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v3 -> ['v3']
#  , v3 -> ['v3']
#  , v2 -> ['v2']
#  , i-avl,avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2 -> ['v2']
#  , v3-v6 -> ['v3', 'v4', 'v5', 'v6']
#  , iii,v2 -> ['iii', 'v2']
#  , v6 -> ['v6']
#  , v2 -> ['v2']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , iii,v6 -> ['iii', 'v6']
# v2, v2 -> ['v2', 'v2']
#  , v1 -> ['v1']
#  , v5,v6 -> ['v5', 'v6']
#  , v2 -> ['v2']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v3,v5 -> ['v3', 'v5']
#  , iii,avl -> ['iii', 'avl']
#  , v6 -> ['v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , v3 -> ['v3']
#  , v1,v3 -> ['v1', 'v3']
#  , v1 -> ['v1']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v4,5,v6 -> ['v4', 'v6']
#  , i-avf,v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v6']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
#  , v2,v3 -> ['v2', 'v3']
#  , v4 -> ['v4']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v2 -> ['v2']
#  , iii-avl -> ['iii', 'avr', 'avl']
#  , i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# v4,   -> ['v4']
#  , v6 -> ['v6']
#  , v2-3 -> ['v2', 'v3']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2,4 -> ['v2']
#  , v1 -> ['v1']
#  , v4-v6 -> ['v4', 'v5', 'v6']
# v1,v2,   -> ['v1', 'v2']
#  , v6 -> ['v6']
#  , v4 -> ['v4']
# v3,   -> ['v3']
#  , i,ii,avl,avr;v5,v6 -> ['i', 'ii', 'avl', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,   -> ['v1']
# v5-6,   -> ['v5', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5 -> ['v5']
#  , v6 -> ['v6']
#  , iii,avl,v1 -> ['iii', 'avl', 'v1']
#  , v2 -> ['v2']
#  , v6 -> ['v6']
#  , v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v1 stark -> []
# v1,   -> ['v1']
#  , v1, v4 -> ['v1', 'v4']
# v1, v2,   -> ['v1', 'v2']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v1 -> ['v1']
#  , iii,avl -> ['iii', 'avl']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5 -> ['v5']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , i,iii,avl,v5 -> ['i', 'iii', 'avl', 'v5']
#  , iii,avf,v1 -> ['iii', 'avf', 'v1']
#  , i,iii -> ['i', 'iii']
#  , v6 -> ['v6']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , i,iii-avr -> ['i', 'iii', 'avr']
#  , v2 -> ['v2']
#  , v1,6 -> ['v1']
# v1-v5,   -> ['v1', 'v2', 'v3', 'v4', 'v5']
#  , v1 -> ['v1']
# v3,   -> ['v3']
# v6,   -> ['v6']
#  , v6 -> ['v6']
#  , iii -> ['iii']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v4 -> ['v4']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v6 -> ['v6']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v4 -> ['v4']
#  , v4 -> ['v4']
#  , v6 -> ['v6']
#  , iii,avf -> ['iii', 'avf']
#  , ii,iii,avr,avf -> ['ii', 'iii', 'avr', 'avf']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v4 -> ['v4']
#  , v3 -> ['v3']
#  , i-v3 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3']
#  , i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
#  , v6 -> ['v6']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , v1 -> ['v1']
#  , v2 -> ['v2']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , v2 -> ['v2']
#  , v5 -> ['v5']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , v1,v2 -> ['v1', 'v2']
#  , v1 -> ['v1']
#  , iii,v5,v6 -> ['iii', 'v5', 'v6']
#  , v1,v6 -> ['v1', 'v6']
#  , iii,avl,v6 -> ['iii', 'avl', 'v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# v3,   -> ['v3']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-v6 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# ii,iii,   -> ['ii', 'iii']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , ii, v1 - v6 -> ['ii', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v1 -> ['v1']
#  , i,ii,avr -> ['i', 'ii', 'avr']
#  , v6 -> ['v6']
# v1,ii,   -> ['v1', 'ii']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v2,v3 -> ['v2', 'v3']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v5 -> ['v5']
#  , v5,v6 -> ['v5', 'v6']
# v5,   -> ['v5']
#  , v6 -> ['v6']
#  , v1,v5,v6 -> ['v1', 'v5', 'v6']
#  , v1 -> ['v1']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , iii -> ['iii']
#  , v6 -> ['v6']
#  , v5 -> ['v5']
#  , v2 -> ['v2']
#  , i-avr -> ['i', 'ii', 'iii', 'avr']
#  , v5 -> ['v5']
#  , iii,avl,v3 -> ['iii', 'avl', 'v3']
#  , v4 -> ['v4']
#  , alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i - avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v2 -> ['v2']
#  , i,ii,iii -> ['i', 'ii', 'iii']
#  , v3,v6 -> ['v3', 'v6']
#  , v6 -> ['v6']
#  , v3 -> ['v3']
#  , v6 -> ['v6']
#  , i,iii,avf -> ['i', 'iii', 'avf']
#  , v6 -> ['v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v5,v6 -> ['v5', 'v6']
#  , v2 -> ['v2']
#  , ii,iii,avf -> ['ii', 'iii', 'avf']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v4 -> ['v4']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v3 -> ['v3']
#  , iii,avl -> ['iii', 'avl']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
#  , v5 -> ['v5']
#  , i-avl,v6 -> ['i', 'ii', 'iii', 'avr', 'avl', 'v6']
#  , v2 -> ['v2']
# i-avf,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i,ii,   -> ['i', 'ii']
#  , v6 -> ['v6']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# iii-avl,v2-v5,   -> ['iii', 'avr', 'avl', 'v2', 'v3', 'v4', 'v5']
#  , v5 -> ['v5']
#  , v6 -> ['v6']
#  , i,iii-avr -> ['i', 'iii', 'avr']
#  , v5 -> ['v5']
#  , v5 -> ['v5']
#  , i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , v4-v6 -> ['v4', 'v5', 'v6']
#  , i-avr,v5 -> ['i', 'ii', 'iii', 'avr', 'v5']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , v1,v2 -> ['v1', 'v2']
#  , v6 -> ['v6']
#  , v6 -> ['v6']
#  , i,iii,avl -> ['i', 'iii', 'avl']
#  , avr -> ['avr']
#  , i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
#  , v6 -> ['v6']
# alles,   -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
#  , i-avr,v3 -> ['i', 'ii', 'iii', 'avr', 'v3']
#  , i,ii,avl-v2 -> ['i', 'ii', 'avl', 'avf', 'v1', 'v2']
#  , v4 -> ['v4']
#  , v1 -> ['v1']
#  , avl -> ['avl']
#  , i,iii,avl,v5 -> ['i', 'iii', 'avl', 'v5']
#  , v5 -> ['v5']
# v3,v4,   -> ['v3', 'v4']
#  , i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
#  , ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# ...
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v6 -> ['v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# v1-v3 -> ['v1', 'v2', 'v3']
# v2 -> ['v2']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# i-v3 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v5,v6 -> ['v5', 'v6']
# ii,avr-v3 -> ['ii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3']
# v4,v5 -> ['v4', 'v5']
# v1,v5 -> ['v1', 'v5']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# i-alf -> ['erroneous']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v6 -> ['v6']
# v1 -> ['v1']
# v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# v4, v5 -> ['v4', 'v5']
# v5 -> ['v5']
# v3 -> ['v3']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# v5 -> ['v5']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# ja -> []
# i-v4 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# v6 -> ['v6']
# v2 -> ['v2']
# v4 -> ['v4']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i,ii -> ['i', 'ii']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# ii,iii,v1,v2 -> ['ii', 'iii', 'v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# iii,v1 -> ['iii', 'v1']
# v2,v4 -> ['v2', 'v4']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v5 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v5 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v5,v6 -> ['v5', 'v6']
# i-v3 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i,avr,v1 -> ['i', 'avr', 'v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i,avl -> ['i', 'avl']
# i,iii,avl -> ['i', 'iii', 'avl']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i,iii-avr -> ['i', 'iii', 'avr']
# i -> ['i']
# v3 -> ['v3']
# ii -> ['ii']
# v3 -> ['v3']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v5 -> ['v5']
# v1 -> ['v1']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v1 -> ['v1']
# v3 -> ['v3']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# v4,6 -> ['v4']
# v4-5 -> ['v4', 'v5']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v5, v6 -> ['v5', 'v6']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# i,avl -> ['i', 'avl']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v3-4 -> ['v3', 'v4']
# v6 -> ['v6']
# v1-6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v5 -> ['v5']
# v3-v6 -> ['v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v2 -> ['v2']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# ii-v1 -> ['ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v5 -> ['v5']
# i,ii,avr,v2 -> ['i', 'ii', 'avr', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v3 -> ['v3']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# v4-5 -> ['v4', 'v5']
# v4 -> ['v4']
# v3 -> ['v3']
# v5,6 -> ['v5']
# v5 -> ['v5']
# alle -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i,ii,avl-avr -> ['i', 'ii']
# v1 -> ['v1']
# ii-avf -> ['ii', 'iii', 'avr', 'avl', 'avf']
# alle abl. -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# ii,iii,v1,v2 -> ['ii', 'iii', 'v1', 'v2']
# i,ii,v1 -> ['i', 'ii', 'v1']
# v6 -> ['v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# v4 -> ['v4']
# i-avl -> ['i', 'ii', 'iii', 'avr', 'avl']
# v1 -> ['v1']
# v1,v2 -> ['v1', 'v2']
# v4 -> ['v4']
# v1,v2 -> ['v1', 'v2']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v2 -> ['v2']
# v1,v2 -> ['v1', 'v2']
# v1 -> ['v1']
# v1 -> ['v1']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i,ii,avl-v2 -> ['i', 'ii', 'avl', 'avf', 'v1', 'v2']
# avl -> ['avl']
# v1,v6 -> ['v1', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i,ii,iii -> ['i', 'ii', 'iii']
# v1,v2,v5 -> ['v1', 'v2', 'v5']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v2 -> ['v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v3 -> ['v3']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v1,v2 -> ['v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# v1,v2 -> ['v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v5 -> ['v5']
# v3 -> ['v3']
# i,iii-avr -> ['i', 'iii', 'avr']
# v2 -> ['v2']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i,iii-avf,v2 -> ['i', 'iii', 'avr', 'avl', 'avf', 'v2']
# v4 -> ['v4']
# v5-6 -> ['v5', 'v6']
# v4-5 -> ['v4', 'v5']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# v4,6 -> ['v4']
# v2-3 -> ['v2', 'v3']
# v3-4 -> ['v3', 'v4']
# v6 -> ['v6']
# v3 -> ['v3']
# v5-6 -> ['v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v2 -> ['v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# v1 -> ['v1']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v2 -> ['v2']
# v3 -> ['v3']
# v3 -> ['v3']
# i-v3 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3']
# v1-v5 -> ['v1', 'v2', 'v3', 'v4', 'v5']
# v2 -> ['v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# v1-v3 -> ['v1', 'v2', 'v3']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v3 -> ['v3']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v2 -> ['v2']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# i,iii-avl -> ['i', 'iii', 'avr', 'avl']
# v1 -> ['v1']
# v5 -> ['v5']
# v1 -> ['v1']
# v1 -> ['v1']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# v1-v4 -> ['v1', 'v2', 'v3', 'v4']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v1 -> ['v1']
# v1 -> ['v1']
# v3 -> ['v3']
# v3 -> ['v3']
# v1-v3 -> ['v1', 'v2', 'v3']
# v5 -> ['v5']
# v5 -> ['v5']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v5 -> ['v5']
# v1-v5 -> ['v1', 'v2', 'v3', 'v4', 'v5']
# v1 -> ['v1']
# v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v2 -> ['v2']
# v2 -> ['v2']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v1-v3 -> ['v1', 'v2', 'v3']
# v1,v5 -> ['v1', 'v5']
# v6 -> ['v6']
# v6 -> ['v6']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1-v4 -> ['v1', 'v2', 'v3', 'v4']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# v1 -> ['v1']
# v1 -> ['v1']
# i,ii,avr -> ['i', 'ii', 'avr']
# ii-avl -> ['ii', 'iii', 'avr', 'avl']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# i,iii,avl -> ['i', 'iii', 'avl']
# v1 -> ['v1']
# i,ii -> ['i', 'ii']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v2 -> ['v2']
# ii -> ['ii']
# v2 -> ['v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v3-v6 -> ['v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v1,v2 -> ['v1', 'v2']
# v3 -> ['v3']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v2 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# i-v5 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v4 -> ['v1', 'v4']
# v2 -> ['v2']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v5 -> ['v5']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1 -> ['v1']
# ii-avl,v1,v2 -> ['ii', 'iii', 'avr', 'avl', 'v1', 'v2']
# v1-v6 -> ['v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v1,v2 -> ['v1', 'v2']
# avl -> ['avl']
# v1 -> ['v1']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-avf -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf']
# v2-v6 -> ['v2', 'v3', 'v4', 'v5', 'v6']
# i-avr -> ['i', 'ii', 'iii', 'avr']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# v6 -> ['v6']
# alles -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
# i-v1 -> ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1']
# v1 -> ['v1']
# v6 -> ['v6']
# v4 -> ['v4']
# v1 -> ['v1']
# v3 -> ['v3']
# v5,v6 -> ['v5', 'v6']
# v1??? -> []
# kontaktprobleme avl ??? -> []
# v6 -> ['v6']
# v6 -> ['v6']
# v1 -> ['v1']
# v5 -> ['v5']
# v6 -> ['v6']
# v6 -> ['v6']
# i??? -> []
# v6 -> ['v6']
# v4 -> ['v4']
# v1??? -> []
# avl??? -> []
# v4 -> ['v4']
# v6???? -> []
# elektroden vertauscht??? -> []
# v4 -> ['v4']
# v6 -> ['v6']
# v1 -> ['v1']
# v4, v5 -> ['v4', 'v5']
# v6 -> ['v6']
# v4 -> ['v4']
# v1 -> ['v1']
# v3,v4-v6 -> ['v3', 'v4', 'v5', 'v6']
# v5 -> ['v5']
# 21799

# %%
# Hightlight the rows that were unparsable even after filter
mask = noise_information.map(lambda x: error_message in str(x))
cleaned_noise_information = noise_information[~mask.any(axis=1)]
print(len(cleaned_noise_information))
print(f"Total lost rows: {len(noise_information) - len(cleaned_noise_information)}")
# Out:
# 21558
# Total lost rows: 241

# %%
# Remove rows from the sig_database that are not present in the cleaned_noise information then apply the changes
sig_database = sig_database.loc[cleaned_noise_information.index]
sig_database[['baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems']] = cleaned_noise_information[['baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems']]
sig_database.reset_index(drop=True, inplace=True)

# %%
del noise_information
del cleaned_noise_information

# %% [markdown]
# # At this point...
# We have parsed the lead information for the four types of noise present in the signals and have removed the unparsable examples from the dataset. Now we will create a dataset where each example is the signal file path that each has 5 possible labels: ['baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems', 'clean']
#
# - a 1 or 0 under the column indicates the status
# - if the signal is clean, all other columns must be 0
#
# The way the signal data is stored is in a (10 sec * sample_rate) length array of length 12 arrays, where each index in the 12 value array refers to a specific lead. We first need to flip the array to be oriented the other way, then create the labels and export the dataset.

# %%
def load_and_transform(df):
    file_path = df['filename_lr']
    signals, meta = load_one_sample(os.path.join(root_directory_path, file_path))
    signals = signals.T # transpose to get each individual signal on it's own row

    noise_types = ['baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems', 'clean']
    classifications = np.zeros((signals.shape[0], len(noise_types)))
    
    for noise_index, type in enumerate(noise_types[:-1]):
        # Get the indexes of the signals that contain this type of noise using the lead code
        codes_for_noise_type = df[type]

        # No Leads have noise
        if codes_for_noise_type != 'clean':
            for code in codes_for_noise_type:
                lead_index = lead_table.index(code)
                classifications[lead_index][noise_index] = 1

    # If no noise it present in the column, mark the clean label as true    
    rows = []
    for lead_index in range(classifications.shape[0]):
        if classifications[lead_index, :-1].any():
            classifications[lead_index, -1] = 0
        else:
            classifications[lead_index, -1] = 1

    rows = []
    for lead_index in range(classifications.shape[0]):
        labels_dict = {noise_types[i]: classifications[lead_index][i] for i in range(len(noise_types))}
        rows.append({'signal': signals[lead_index].tolist()[0]} | labels_dict)

    return rows

# %%
transformed_signal = load_and_transform(sig_database.iloc[0])

# %%
# Apply this transform to the entire dataset, producing a new dataframe, export it to a file
# Initialize an empty list to collect all rows
current_selection = []
max_count = 5000
count = 0
file_count = 0

# Use tqdm to monitor the progress
for index, row in tqdm.tqdm(sig_database.iterrows(), total=sig_database.shape[0], desc="Processing rows"):
    formatted_data = load_and_transform(row)
    current_selection.extend(formatted_data)
    count += 1

    # Write the current batch to a dataframe
    if count % max_count == 0 or index == sig_database.shape[0] - 1:
        data_to_export = pd.DataFrame(current_selection)
        data_to_export.to_parquet(f'ecg_noise_dataset_{file_count}.parquet', engine='pyarrow')
        # Reset for next batch
        current_selection.clear()
        count = 0
        file_count += 1
# Out:
# Processing rows: 100%|██████████| 21558/21558 [00:45<00:00, 472.63it/s]

# %%
data = pd.DataFrame()
for file in os.listdir():
    if file.split('.')[-1] == 'parquet':
        print(f'Loading: {file}')
        new_data = pd.read_parquet(file)
        data = pd.concat([data, new_data])
data

# %%
data['label_combination'] = data[['baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems', 'clean']].apply(
    lambda row: ','.join([col for col, val in zip(row.index, row) if val == 1.0]),
    axis=1
)

# Get the distribution of these label combinations
label_distribution = data['label_combination'].value_counts()
print(label_distribution)
